# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
import pyAgrum.causal as csl
import pyAgrum.causal.notebook as cslnb


import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from plotnine import *
from mizani.formatters import percent_format
# %matplotlib inline
import sklearn, shap, xgboost

# %%
def sigmoid(x):
    return 1/(1 + np.exp(-x))

# %% [markdown]
# ## Data Generation Model

# %%
bn=gum.fastBN("coupon->loyalty->renewal;corporate customer->yearly consumption[5]->coupon;corporate customer->loyalty->recent visit")
bn.addArc("yearly consumption","loyalty")
bn.addArc("coupon","recent visit")
bn
# Out:
# (pyAgrum.BayesNet<double>@000002E26F963DD0) BN{nodes: 6, arcs: 8, domainSize: 160, dim: 74}

# %%
bn.cpt("corporate customer").fillWith([0.4,0.6])
# Out:
# (pyAgrum.Potential<double>@000002E27241DDE0)
#   corporate custome|
# 0        |1        |
# ---------|---------|
#  0.4000  | 0.6000  |

# %%
bn.cpt("yearly consumption")[{"corporate customer":0}] = [0.3, 0.25, 0.2, 0.15, 0.1]
bn.cpt("yearly consumption")[{"corporate customer":1}] = [0.1, 0.15, 0.2, 0.25, 0.3]
bn.cpt("yearly consumption").normalizeAsCPT()
# Out:
# (pyAgrum.Potential<double>@000002E27241D8E0)
#       ||  yearly consumption                             |
# corpor||0        |1        |2        |3        |4        |
# ------||---------|---------|---------|---------|---------|
# 0     || 0.3000  | 0.2500  | 0.2000  | 0.1500  | 0.1000  |
# 1     || 0.1000  | 0.1500  | 0.2000  | 0.2500  | 0.3000  |

# %%
for i in range(5):
    monthly = (2*i+2) / 12
    bn.cpt("coupon")[{"yearly consumption":i}]=[1 - monthly,monthly]
bn.cpt("coupon").normalizeAsCPT()
# Out:
# (pyAgrum.Potential<double>@000002E27241DE60)
#       ||  coupon           |
# yearly||0        |1        |
# ------||---------|---------|
# 0     || 0.8333  | 0.1667  |
# 1     || 0.6667  | 0.3333  |
# 2     || 0.5000  | 0.5000  |
# 3     || 0.3333  | 0.6667  |
# 4     || 0.1667  | 0.8333  |

# %%
for i in range(5):
    bn.cpt("loyalty")[{"corporate customer":0,"coupon":0,"yearly consumption":i}]=[0.8-i*0.07,0.2+i*0.07]
    bn.cpt("loyalty")[{"corporate customer":0,"coupon":1,"yearly consumption":i}]=[0.7-i*0.15,0.3+i*0.15]
    bn.cpt("loyalty")[{"corporate customer":1,"coupon":0,"yearly consumption":i}]=[0.3,0.7]
    bn.cpt("loyalty")[{"corporate customer":1,"coupon":1,"yearly consumption":i}]=[0.3,0.7]
bn.cpt("loyalty").normalizeAsCPT()
# Out:
# (pyAgrum.Potential<double>@000002E27241DBA0)
#                     ||  loyalty          |
# coupon|corpor|yearly||0        |1        |
# ------|------|------||---------|---------|
# 0     |0     |0     || 0.8000  | 0.2000  |
# 1     |0     |0     || 0.7000  | 0.3000  |
# 0     |1     |0     || 0.3000  | 0.7000  |
# 1     |1     |0     || 0.3000  | 0.7000  |
# 0     |0     |1     || 0.7300  | 0.2700  |
# 1     |0     |1     || 0.5500  | 0.4500  |
# [...8 more line(s) ...]
# 0     |1     |3     || 0.3000  | 0.7000  |
# 1     |1     |3     || 0.3000  | 0.7000  |
# 0     |0     |4     || 0.5200  | 0.4800  |
# 1     |0     |4     || 0.1000  | 0.9000  |
# 0     |1     |4     || 0.3000  | 0.7000  |
# 1     |1     |4     || 0.3000  | 0.7000  |

# %%
bn.cpt("recent visit")[{"loyalty":0,"coupon":0}]=[0.85,0.15] #was 0.15
bn.cpt("recent visit")[{"loyalty":0,"coupon":1}]=[0.6,0.4]   #was 0.35
bn.cpt("recent visit")[{"loyalty":1,"coupon":0}]=[0.35,0.65] #was 0.65
bn.cpt("recent visit")[{"loyalty":1,"coupon":1}]=[0.1,0.9]   #was 0.9
bn.cpt("recent visit")
# Out:
# (pyAgrum.Potential<double>@000002E27241D960)
#              ||  recent visit     |
# loyalt|coupon||0        |1        |
# ------|------||---------|---------|
# 0     |0     || 0.8500  | 0.1500  |
# 1     |0     || 0.3500  | 0.6500  |
# 0     |1     || 0.6000  | 0.4000  |
# 1     |1     || 0.1000  | 0.9000  |

# %%
bn.cpt("renewal")[{"loyalty":0}]=[0.9,0.1]
bn.cpt("renewal")[{"loyalty":1}]=[0.1,0.9]
bn.cpt("renewal")
# Out:
# (pyAgrum.Potential<double>@000002E27241DA40)
#       ||  renewal          |
# loyalt||0        |1        |
# ------||---------|---------|
# 0     || 0.9000  | 0.1000  |
# 1     || 0.1000  | 0.9000  |

# %%
ie=gum.LazyPropagation(bn)
ie.makeInference()
ie.posterior("renewal")
# Out:
# (pyAgrum.Potential<double>@000002E27241FDC0)
#   renewal          |
# 0        |1        |
# ---------|---------|
#  0.4296  | 0.5704  |

# %%
ie.evidenceImpact("renewal", ["yearly consumption","corporate customer","coupon"])
# Out:
# (pyAgrum.Potential<double>@000002E27241FDA0)
#                     ||  renewal          |
# corpor|yearly|coupon||0        |1        |
# ------|------|------||---------|---------|
# 0     |0     |0     || 0.7400  | 0.2600  |
# 1     |0     |0     || 0.3400  | 0.6600  |
# 0     |1     |0     || 0.6840  | 0.3160  |
# 1     |1     |0     || 0.3400  | 0.6600  |
# 0     |2     |0     || 0.6280  | 0.3720  |
# 1     |2     |0     || 0.3400  | 0.6600  |
# [...8 more line(s) ...]
# 0     |2     |1     || 0.4200  | 0.5800  |
# 1     |2     |1     || 0.3400  | 0.6600  |
# 0     |3     |1     || 0.3000  | 0.7000  |
# 1     |3     |1     || 0.3400  | 0.6600  |
# 0     |4     |1     || 0.1800  | 0.8200  |
# 1     |4     |1     || 0.3400  | 0.6600  |

# %%
ie.evidenceImpact("renewal", ["corporate customer","yearly consumption","coupon"]).extract({'coupon':1})
# Out:
# (pyAgrum.Potential<double>@000002E27241FD80)
#              ||  renewal          |
# corpor|yearly||0        |1        |
# ------|------||---------|---------|
# 0     |0     || 0.6600  | 0.3400  |
# 1     |0     || 0.3400  | 0.6600  |
# 0     |1     || 0.5400  | 0.4600  |
# 1     |1     || 0.3400  | 0.6600  |
# 0     |2     || 0.4200  | 0.5800  |
# 1     |2     || 0.3400  | 0.6600  |
# 0     |3     || 0.3000  | 0.7000  |
# 1     |3     || 0.3400  | 0.6600  |
# 0     |4     || 0.1800  | 0.8200  |
# 1     |4     || 0.3400  | 0.6600  |

# %% [markdown]
# ## Sensitivity to Variable Selection

# %%
size=500000
foreground_size=5000
background_size=1000

#gum.generateCSV(bn,"data.csv",5000,random_order=True)
generator=gum.BNDatabaseGenerator(bn)
generator.setRandomVarOrder()
generator.drawSamples(size)
generator.toCSV('renewal_all.csv')
data=pd.read_csv('renewal_all.csv').sample(frac=1)
data.to_csv('renewal_all.csv', index=False)

# %% [markdown]
# ### Selecting all known features

# %%
y=data["renewal"]
X=data.drop(["renewal","loyalty"], axis=1).astype('float')

X_train,X_test,y_train,y_test = sklearn.model_selection.train_test_split(X, y, stratify=y)

dtrain = xgboost.DMatrix(X_train, label=y_train)
dtest = xgboost.DMatrix(X_test, label=y_test)

params =  { "eta": 0.1, "subsample": 0.95, "max_depth": 4, "objective": "binary:logistic", "eval_metric":['logloss']}
model_1 = xgboost.train(
    params, dtrain, num_boost_round=10000,
    evals=((dtest, "test"),), early_stopping_rounds=20, verbose_eval=100
)

fg = X_test.iloc[background_size:foreground_size+background_size]
bg = X_test.iloc[:background_size]

explainer = shap.Explainer(model_1, bg)
shap_values = explainer.shap_values(fg)
# Out:
# [0]	test-logloss:0.66971
# [100]	test-logloss:0.56072
# [104]	test-logloss:0.56072
#  97%|=================== | 4835/5000 [00:17<00:00]

# %%
sns.set_theme()
shap.summary_plot(shap_values, features=fg)

# %% [markdown]
# ### Excluding recent visit

# %%
X=data.drop(["renewal","loyalty","recent visit"], axis=1).astype('float')

X_train,X_test,y_train,y_test = sklearn.model_selection.train_test_split(X, y, stratify=y)

dtrain = xgboost.DMatrix(X_train, label=y_train)
dtest = xgboost.DMatrix(X_test, label=y_test)

model_2 = xgboost.train(
    params, dtrain, num_boost_round=2000,
    evals=((dtest, "test"),), early_stopping_rounds=20, verbose_eval=500
)

fg = X_test.iloc[background_size:foreground_size+background_size]
bg = X_test.iloc[:background_size]

explainer = shap.Explainer(model_2, bg)
shap_values = explainer.shap_values(fg)
# Out:
# [0]	test-logloss:0.68179
# [100]	test-logloss:0.63041
# 100%|===================| 4980/5000 [00:14<00:00]

# %%
shap.summary_plot(shap_values, features=fg)

# %% [markdown]
# ## Correct Calculation Of Average Causal Effect

# %%
import pyAgrum.lib.notebook as gnb
gnb.showInference(bn)

# %%
cm=csl.CausalModel(bn)
cslnb.showCausalImpact(cm,"renewal", {"coupon"})
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 2px solid #FFFFFF;
#       valign:middle;
#       background-color: #FDFDFD;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="127pt" height="180pt" viewBox="0.00 0.00 127.00 180.00">
# <g id="graph0" class="graph" transform="scale(0.54 0.54) rotate(0) translate(4 328)">
# <title>G</title>
# <!-- coupon -->
# <g id="node1" class="node">
# <title>coupon</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="144.35" cy="-162" rx="38.19" ry="18"/>
# <text text-anchor="middle" x="144.35" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">coupon</text>
# </g>
# <!-- loyalty -->
# <g id="node2" class="node">
# <title>loyalty</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="78.35" cy="-90" rx="34.39" ry="18"/>
# <text text-anchor="middle" x="78.35" y="-86.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">loyalty</text>
# </g>
# <!-- coupon&#45;&gt;loyalty -->
# <g id="edge1" class="edge">
# <title>coupon-&gt;loyalty</title>
# <path fill="none" stroke="#4a4a4a" d="M128.64,-145.8C119.91,-136.54 108.76,-124.71 99.11,-114.48"/>
# <path fill="none" stroke="#4a4a4a" d="M130.1,-144.43C121.37,-135.17 110.21,-123.34 100.56,-113.1"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="102.22,-111.22 92.81,-106.34 97.12,-116.02 102.22,-111.22"/>
# </g>
# <!-- recent visit -->
# <g id="node6" class="node">
# <title>recent visit</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="144.35" cy="-18" rx="50.09" ry="18"/>
# <text text-anchor="middle" x="144.35" y="-14.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">recent visit</text>
# </g>
# <!-- coupon&#45;&gt;recent visit -->
# <g id="edge7" class="edge">
# <title>coupon-&gt;recent visit</title>
# <path fill="none" stroke="#4a4a4a" d="M143.35,-143.87C143.35,-119.67 143.35,-75.21 143.35,-46.39"/>
# <path fill="none" stroke="#4a4a4a" d="M145.35,-143.87C145.35,-119.67 145.35,-75.21 145.35,-46.39"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="147.85,-46.19 144.35,-36.19 140.85,-46.19 147.85,-46.19"/>
# </g>
# <!-- renewal -->
# <g id="node3" class="node">
# <title>renewal</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="38.35" cy="-18" rx="38.19" ry="18"/>
# <text text-anchor="middle" x="38.35" y="-14.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">renewal</text>
# </g>
# <!-- loyalty&#45;&gt;renewal -->
# <g id="edge2" class="edge">
# <title>loyalty-&gt;renewal</title>
# <path fill="none" stroke="#4a4a4a" d="M68,-72.91C63.22,-64.54 57.31,-54.21 51.98,-44.87"/>
# <path fill="none" stroke="#4a4a4a" d="M69.74,-71.91C64.95,-63.55 59.05,-53.21 53.71,-43.87"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="55.76,-42.42 47.76,-35.47 49.68,-45.89 55.76,-42.42"/>
# </g>
# <!-- loyalty&#45;&gt;recent visit -->
# <g id="edge5" class="edge">
# <title>loyalty-&gt;recent visit</title>
# <path fill="none" stroke="#4a4a4a" d="M92.27,-72.78C100.74,-63.79 111.58,-52.29 121.12,-42.18"/>
# <path fill="none" stroke="#4a4a4a" d="M93.72,-74.15C102.2,-65.16 113.04,-53.67 122.57,-43.55"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="124.51,-45.14 128.82,-35.47 119.41,-40.34 124.51,-45.14"/>
# </g>
# <!-- corporate customer -->
# <g id="node4" class="node">
# <title>corporate customer</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="89.35" cy="-306" rx="81.79" ry="18"/>
# <text text-anchor="middle" x="89.35" y="-302.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">corporate customer</text>
# </g>
# <!-- corporate customer&#45;&gt;loyalty -->
# <g id="edge6" class="edge">
# <title>corporate customer-&gt;loyalty</title>
# <path fill="none" stroke="#4a4a4a" d="M73.33,-288.87C65.42,-279 56.64,-265.95 52.39,-252.29 38.21,-205.62 54.01,-149.49 66.17,-117.08"/>
# <path fill="none" stroke="#4a4a4a" d="M74.89,-287.62C67.08,-277.89 58.3,-264.84 54.3,-251.71 40.13,-206.16 55.94,-150.03 68.05,-117.78"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="70.49,-118.4 70.88,-107.81 63.97,-115.85 70.49,-118.4"/>
# </g>
# <!-- yearly consumption -->
# <g id="node5" class="node">
# <title>yearly consumption</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="144.35" cy="-234" rx="81.79" ry="18"/>
# <text text-anchor="middle" x="144.35" y="-230.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">yearly consumption</text>
# </g>
# <!-- corporate customer&#45;&gt;yearly consumption -->
# <g id="edge4" class="edge">
# <title>corporate customer-&gt;yearly consumption</title>
# <path fill="none" stroke="#4a4a4a" d="M101.87,-287.44C108.56,-278.92 116.79,-268.45 124.17,-259.06"/>
# <path fill="none" stroke="#4a4a4a" d="M103.45,-288.67C110.14,-280.16 118.36,-269.69 125.74,-260.3"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="127.73,-261.81 131.16,-251.79 122.22,-257.49 127.73,-261.81"/>
# </g>
# <!-- yearly consumption&#45;&gt;coupon -->
# <g id="edge3" class="edge">
# <title>yearly consumption-&gt;coupon</title>
# <path fill="none" stroke="#4a4a4a" d="M143.35,-215.7C143.35,-207.98 143.35,-198.71 143.35,-190.11"/>
# <path fill="none" stroke="#4a4a4a" d="M145.35,-215.7C145.35,-207.98 145.35,-198.71 145.35,-190.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="147.85,-190.1 144.35,-180.1 140.85,-190.1 147.85,-190.1"/>
# </g>
# <!-- yearly consumption&#45;&gt;loyalty -->
# <g id="edge8" class="edge">
# <title>yearly consumption-&gt;loyalty</title>
# <path fill="none" stroke="#4a4a4a" d="M124.53,-216.83C114.71,-207.13 103.47,-194.27 96.45,-180.45 86.6,-160.86 81.84,-136.71 79.52,-118.38"/>
# <path fill="none" stroke="#4a4a4a" d="M125.93,-215.4C116.22,-205.81 104.98,-192.95 98.24,-179.55 88.56,-160.47 83.8,-136.32 81.51,-118.13"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="83.99,-117.82 79.42,-108.26 77.03,-118.58 83.99,-117.82"/>
# </g>
# </g>
# </svg><br><center><small><em>Causal Model</em></small></center></div><div class="floating-box">$$\begin{equation*}P( renewal \mid \hookrightarrow\mkern-6.5mucoupon) = \sum_{yearly consumption}{P\left(renewal\mid coupon,yearly consumption\right) \cdot P\left(yearly consumption\right)}\end{equation*}$$<br><center><small><em>Explanation : backdoor ['yearly consumption'] found.</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='1'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>renewal</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>coupon</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#c3ba64;text-align:right;'>0.4664</td><td style='color:black;background-color:#bac364;text-align:right;'>0.5336</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#ccb164;text-align:right;'>0.3960</td><td style='color:black;background-color:#b1cc64;text-align:right;'>0.6040</td></tr>
# </table><br><center><small><em>Impact</em></small></center></div>

# %%
f, p, s = gum.causal.causalImpact(cm=cm, on="renewal", doing={"coupon"})
average_uplift = (p.extract({'coupon':1}) - p.extract({'coupon':0}))[1]
print(f'Average Uplift (ground truth) = {average_uplift:.2%}')
# Out:
# Average Uplift (ground truth) = 7.04%

# %% [markdown]
# ### ICE Calculation
# Feature selection should satisfy back-door criterion (e.g. model_2)

# %%
population = X_test.copy()
population['coupon'] = 1
population['yhat'] = model_2.predict(xgboost.DMatrix(population))
np.mean(population['yhat'])
# Out:
# 0.6042916

# %%
population = X_test.copy()
population['coupon'] = 0
population['yhat'] = model_2.predict(xgboost.DMatrix(population))
np.mean(population['yhat'])
# Out:
# 0.53259045

# %%
print(f'Average Uplift Estimate = {np.mean(average_uplift):.2%} +/- {np.std(average_uplift):.2%}')
# Out:
# Average Uplift Estimate = 7.04% +/- 0.00%

# %% [markdown]
# It also works with a simpler selection.

# %%
X=data.drop(["renewal","loyalty","recent visit","corporate customer"], axis=1).astype('float')

X_train,X_test,y_train,y_test = sklearn.model_selection.train_test_split(X, y, stratify=y)

dtrain = xgboost.DMatrix(X_train, label=y_train)
dtest = xgboost.DMatrix(X_test, label=y_test)

model_3 = xgboost.train(
    params, dtrain, num_boost_round=200000,
    evals=((dtest, "test"),), early_stopping_rounds=20, verbose_eval=100
)
# Out:
# [0]	test-logloss:0.68723
# [58]	test-logloss:0.66178

# %%
population = X_test.copy()
population['coupon'] = 1
population['yhat'] = model_3.predict(xgboost.DMatrix(population))
np.mean(population['yhat'])
# Out:
# 0.6036862

# %%
population = X_test.copy()
population['coupon'] = 0
population['yhat'] = model_3.predict(xgboost.DMatrix(population))
np.mean(population['yhat'])
# Out:
# 0.533058

# %% [markdown]
# ### SHAP Calculation
#
# Feature selection should satisfy back-door criterion (e.g. model_2)
# True calculation should involve Shapley-Taylor diagonal, which does not exist in open-source ?

# %%
X=data.drop(["renewal","loyalty","recent visit"], axis=1).astype('float')

X_train,X_test,y_train,y_test = sklearn.model_selection.train_test_split(X, y, stratify=y)

dtrain = xgboost.DMatrix(X_train, label=y_train)
dtest = xgboost.DMatrix(X_test, label=y_test)

model_2 = xgboost.train(
    params, dtrain, num_boost_round=2000,
    evals=((dtest, "test"),), early_stopping_rounds=20, verbose_eval=100
)

fg, bg, _, _ = sklearn.model_selection.train_test_split(X_test, y_test, stratify=y_test,
                                                        test_size=background_size,
                                                        train_size=foreground_size)

explainer = shap.Explainer(model_2, bg)
print(explainer.data.shape)
sigmoid(explainer.expected_value)
# Out:
# [0]	test-logloss:0.68179
# [77]	test-logloss:0.63120
# (100, 3)
# 0.5789320668887132

# %%
shap_values = explainer.shap_values(fg)

# %%
sv = pd.DataFrame(shap_values, columns=X.columns, index=fg.index)

# %%
np.mean(data.renewal)
# Out:
# 0.570688

# %%
np.mean(y_test)
# Out:
# 0.570688

# %%
np.mean(model_2.predict(xgboost.DMatrix(bg)))
# Out:
# 0.5701192

# %%
sigmoid(np.mean(model_2.predict(xgboost.DMatrix(bg), output_margin=True)))
# Out:
# 0.5721404310616999

# %%
population = fg.copy()
population['shap'] = sigmoid(sv['coupon'] + explainer.expected_value)
population.groupby('coupon').agg(shap=('shap','mean')).reset_index()
# Out:
#    coupon      shap
# 0     0.0  0.528569
# 1     1.0  0.606424

# %%
population = fg.copy()
population['shap'] = sv['coupon'] 
results = population.groupby('coupon').agg(shap_min=('shap','min'),
                                           shap_max=('shap','max'),
                                           shap_avg=('shap','mean')).reset_index()
for v in ('shap_min', 'shap_max', 'shap_avg'):
    results[v] = sigmoid(results[v] + explainer.expected_value)
results
# Out:
#    coupon  shap_min  shap_max  shap_avg
# 0     0.0  0.436215  0.561117  0.528661
# 1     1.0  0.589343  0.650314  0.606596

# %% [markdown]
# ### Shapley-Taylor Interaction Values
#
# Unfortunately the group_shap library is SAP proprietary code and cannot be published. The diagonal of the Shapley-Taylor interaction values is "close" to the ICE. The main difference is that it is computed in the log-odds space.

# %%
shap.summary_plot(smv.to_numpy(), features=fg)

# %% [markdown]
# Here we get for coupon an average contribution on the whole population, instead of a local contribution.

# %%
population = fg.copy()
population['shap'] = smv['coupon']
results = population.groupby('coupon').agg(shap_min=('shap','min'),
                                 shap_max=('shap','max')).reset_index()
for v in ('shap_min', 'shap_max'):
    results[v] = sigmoid(results[v] + gexpl.baseline)
results
# Out:
#    coupon  shap_min  shap_max
# 0     0.0  0.534112  0.534112
# 1     1.0  0.605594  0.605594

# %% [markdown]
# ## Uplift

# %% [markdown]
# ### SHAP Values for coupons are non-zero for corporate customers
# However coupons have no causal effect on corporate customers, by design of the data generator.

# %%
fg = X_test.iloc[background_size:background_size+foreground_size]
bg = X_test.iloc[:background_size]

fg_cc = fg[fg['corporate customer'] == 1]
explainer = shap.Explainer(model_2, bg)
shap_values = explainer.shap_values(fg_cc)
shap.summary_plot(shap_values, features=fg_cc)

# %%
fg_ncc = fg[fg['corporate customer'] == 0]
explainer = shap.Explainer(model_2, bg)
shap_values = explainer.shap_values(fg_ncc)
shap.summary_plot(shap_values, features=fg_ncc)

# %% [markdown]
# ### Correct Calculation

# %%
cslnb.showCausalImpact(cm,"renewal", {"coupon"}, knowing={"corporate customer", "yearly consumption"})
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 2px solid #FFFFFF;
#       valign:middle;
#       background-color: #FDFDFD;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="127pt" height="180pt" viewBox="0.00 0.00 127.00 180.00">
# <g id="graph0" class="graph" transform="scale(0.54 0.54) rotate(0) translate(4 328)">
# <title>G</title>
# <!-- coupon -->
# <g id="node1" class="node">
# <title>coupon</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="144.35" cy="-162" rx="38.19" ry="18"/>
# <text text-anchor="middle" x="144.35" y="-158.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">coupon</text>
# </g>
# <!-- loyalty -->
# <g id="node2" class="node">
# <title>loyalty</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="78.35" cy="-90" rx="34.39" ry="18"/>
# <text text-anchor="middle" x="78.35" y="-86.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">loyalty</text>
# </g>
# <!-- coupon&#45;&gt;loyalty -->
# <g id="edge1" class="edge">
# <title>coupon-&gt;loyalty</title>
# <path fill="none" stroke="#4a4a4a" d="M128.64,-145.8C119.91,-136.54 108.76,-124.71 99.11,-114.48"/>
# <path fill="none" stroke="#4a4a4a" d="M130.1,-144.43C121.37,-135.17 110.21,-123.34 100.56,-113.1"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="102.22,-111.22 92.81,-106.34 97.12,-116.02 102.22,-111.22"/>
# </g>
# <!-- recent visit -->
# <g id="node6" class="node">
# <title>recent visit</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="144.35" cy="-18" rx="50.09" ry="18"/>
# <text text-anchor="middle" x="144.35" y="-14.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">recent visit</text>
# </g>
# <!-- coupon&#45;&gt;recent visit -->
# <g id="edge7" class="edge">
# <title>coupon-&gt;recent visit</title>
# <path fill="none" stroke="#4a4a4a" d="M143.35,-143.87C143.35,-119.67 143.35,-75.21 143.35,-46.39"/>
# <path fill="none" stroke="#4a4a4a" d="M145.35,-143.87C145.35,-119.67 145.35,-75.21 145.35,-46.39"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="147.85,-46.19 144.35,-36.19 140.85,-46.19 147.85,-46.19"/>
# </g>
# <!-- renewal -->
# <g id="node3" class="node">
# <title>renewal</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="38.35" cy="-18" rx="38.19" ry="18"/>
# <text text-anchor="middle" x="38.35" y="-14.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">renewal</text>
# </g>
# <!-- loyalty&#45;&gt;renewal -->
# <g id="edge2" class="edge">
# <title>loyalty-&gt;renewal</title>
# <path fill="none" stroke="#4a4a4a" d="M68,-72.91C63.22,-64.54 57.31,-54.21 51.98,-44.87"/>
# <path fill="none" stroke="#4a4a4a" d="M69.74,-71.91C64.95,-63.55 59.05,-53.21 53.71,-43.87"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="55.76,-42.42 47.76,-35.47 49.68,-45.89 55.76,-42.42"/>
# </g>
# <!-- loyalty&#45;&gt;recent visit -->
# <g id="edge5" class="edge">
# <title>loyalty-&gt;recent visit</title>
# <path fill="none" stroke="#4a4a4a" d="M92.27,-72.78C100.74,-63.79 111.58,-52.29 121.12,-42.18"/>
# <path fill="none" stroke="#4a4a4a" d="M93.72,-74.15C102.2,-65.16 113.04,-53.67 122.57,-43.55"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="124.51,-45.14 128.82,-35.47 119.41,-40.34 124.51,-45.14"/>
# </g>
# <!-- corporate customer -->
# <g id="node4" class="node">
# <title>corporate customer</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="89.35" cy="-306" rx="81.79" ry="18"/>
# <text text-anchor="middle" x="89.35" y="-302.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">corporate customer</text>
# </g>
# <!-- corporate customer&#45;&gt;loyalty -->
# <g id="edge6" class="edge">
# <title>corporate customer-&gt;loyalty</title>
# <path fill="none" stroke="#4a4a4a" d="M73.33,-288.87C65.42,-279 56.64,-265.95 52.39,-252.29 38.21,-205.62 54.01,-149.49 66.17,-117.08"/>
# <path fill="none" stroke="#4a4a4a" d="M74.89,-287.62C67.08,-277.89 58.3,-264.84 54.3,-251.71 40.13,-206.16 55.94,-150.03 68.05,-117.78"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="70.49,-118.4 70.88,-107.81 63.97,-115.85 70.49,-118.4"/>
# </g>
# <!-- yearly consumption -->
# <g id="node5" class="node">
# <title>yearly consumption</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="144.35" cy="-234" rx="81.79" ry="18"/>
# <text text-anchor="middle" x="144.35" y="-230.3" font-family="Times New Roman,serif" font-size="14.00" fill="white">yearly consumption</text>
# </g>
# <!-- corporate customer&#45;&gt;yearly consumption -->
# <g id="edge4" class="edge">
# <title>corporate customer-&gt;yearly consumption</title>
# <path fill="none" stroke="#4a4a4a" d="M101.87,-287.44C108.56,-278.92 116.79,-268.45 124.17,-259.06"/>
# <path fill="none" stroke="#4a4a4a" d="M103.45,-288.67C110.14,-280.16 118.36,-269.69 125.74,-260.3"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="127.73,-261.81 131.16,-251.79 122.22,-257.49 127.73,-261.81"/>
# </g>
# <!-- yearly consumption&#45;&gt;coupon -->
# <g id="edge3" class="edge">
# <title>yearly consumption-&gt;coupon</title>
# <path fill="none" stroke="#4a4a4a" d="M143.35,-215.7C143.35,-207.98 143.35,-198.71 143.35,-190.11"/>
# <path fill="none" stroke="#4a4a4a" d="M145.35,-215.7C145.35,-207.98 145.35,-198.71 145.35,-190.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="147.85,-190.1 144.35,-180.1 140.85,-190.1 147.85,-190.1"/>
# </g>
# <!-- yearly consumption&#45;&gt;loyalty -->
# <g id="edge8" class="edge">
# <title>yearly consumption-&gt;loyalty</title>
# <path fill="none" stroke="#4a4a4a" d="M124.53,-216.83C114.71,-207.13 103.47,-194.27 96.45,-180.45 86.6,-160.86 81.84,-136.71 79.52,-118.38"/>
# <path fill="none" stroke="#4a4a4a" d="M125.93,-215.4C116.22,-205.81 104.98,-192.95 98.24,-179.55 88.56,-160.47 83.8,-136.32 81.51,-118.13"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="83.99,-117.82 79.42,-108.26 77.03,-118.58 83.99,-117.82"/>
# </g>
# </g>
# </svg><br><center><small><em>Causal Model</em></small></center></div><div class="floating-box">$$\begin{equation*}P( renewal \mid \hookrightarrow\mkern-6.5mucorporate customer,\hookrightarrow\mkern-6.5mucoupon,\hookrightarrow\mkern-6.5muyearly consumption) = \sum_{loyalty}{P\left(renewal\mid loyalty\right) \cdot P\left(loyalty\mid corporate customer,coupon,yearly consumption\right)}\end{equation*}$$<br><center><small><em>Explanation : Do-calculus computations</em></small></center></div><div class="floating-box"><table style="border:1px solid black;">
# <tr><th colspan='3'></th>
#       <th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>renewal</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>yearly consumption</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>corporate customer</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>coupon</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'>
#             <center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#a0dd64;text-align:right;'>0.7400</td><td style='color:black;background-color:#dda064;text-align:right;'>0.2600</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#aad364;text-align:right;'>0.6600</td><td style='color:black;background-color:#d3aa64;text-align:right;'>0.3400</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan =

# %% [markdown]
# ### Theorem: do(X) can be replaced with X if context satisfies backdoor-criterion

# %%
f, p, s = gum.causal.causalImpact(cm=cm, on="renewal", doing={"coupon"}, knowing={'yearly consumption','corporate customer'})
p
# Out:
# (pyAgrum.Potential<double>@000002E27F3433C0)
#                     ||  renewal          |
# coupon|corpor|yearly||0        |1        |
# ------|------|------||---------|---------|
# 0     |0     |0     || 0.7400  | 0.2600  |
# 1     |0     |0     || 0.6600  | 0.3400  |
# 0     |1     |0     || 0.3400  | 0.6600  |
# 1     |1     |0     || 0.3400  | 0.6600  |
# 0     |0     |1     || 0.6840  | 0.3160  |
# 1     |0     |1     || 0.5400  | 0.4600  |
# [...8 more line(s) ...]
# 0     |1     |3     || 0.3400  | 0.6600  |
# 1     |1     |3     || 0.3400  | 0.6600  |
# 0     |0     |4     || 0.5160  | 0.4840  |
# 1     |0     |4     || 0.1800  | 0.8200  |
# 0     |1     |4     || 0.3400  | 0.6600  |
# 1     |1     |4     || 0.3400  | 0.6600  |

# %%
ie.evidenceImpact("renewal", ["yearly consumption","corporate customer", "coupon"]) - p
# Out:
# (pyAgrum.Potential<double>@000002E27F343E80)
#                     ||  renewal          |
# corpor|yearly|coupon||0        |1        |
# ------|------|------||---------|---------|
# 0     |0     |0     || 0.0000  | 0.0000  |
# 1     |0     |0     || 0.0000  | 0.0000  |
# 0     |1     |0     || 0.0000  | 0.0000  |
# 1     |1     |0     || 0.0000  | 0.0000  |
# 0     |2     |0     || -0.0000 | -0.0000 |
# 1     |2     |0     || 0.0000  | 0.0000  |
# [...8 more line(s) ...]
# 0     |2     |1     || 0.0000  | 0.0000  |
# 1     |2     |1     || 0.0000  | 0.0000  |
# 0     |3     |1     || 0.0000  | 0.0000  |
# 1     |3     |1     || 0.0000  | 0.0000  |
# 0     |4     |1     || 0.0000  | 0.0000  |
# 1     |4     |1     || 0.0000  | 0.0000  |

# %% [markdown]
# ### Wrap Up

# %%
uplift = (ie.evidenceImpact("renewal", ["corporate customer", "yearly consumption","coupon"]).extract({'coupon':1}) 
          - ie.evidenceImpact("renewal", ["corporate customer", "yearly consumption","coupon"]).extract({'coupon':0}))
uplift
# Out:
# (pyAgrum.Potential<double>@000002E27F343740)
#              ||  renewal          |
# corpor|yearly||0        |1        |
# ------|------||---------|---------|
# 0     |0     || -0.0800 | 0.0800  |
# 1     |0     || 0.0000  | 0.0000  |
# 0     |1     || -0.1440 | 0.1440  |
# 1     |1     || 0.0000  | 0.0000  |
# 0     |2     || -0.2080 | 0.2080  |
# 1     |2     || 0.0000  | 0.0000  |
# 0     |3     || -0.2720 | 0.2720  |
# 1     |3     || 0.0000  | 0.0000  |
# 0     |4     || -0.3360 | 0.3360  |
# 1     |4     || 0.0000  | 0.0000  |

# %% [markdown]
# ### Using a Predictive Model

# %%
apply_df = X_test.copy()
apply_df['uplift'] = model_2.predict(xgboost.DMatrix(apply_df.assign(coupon=1))) - model_2.predict(xgboost.DMatrix(apply_df.assign(coupon=0)))
result = apply_df.groupby(['yearly consumption','corporate customer']).agg(frequency=('uplift','count'),
                                                                           predicted = ('uplift', 'mean')).reset_index()
expected = []
for i in range(len(result)):
    row = result.iloc[i]
    expected.append(uplift.extract({'yearly consumption':int(row['yearly consumption']),
                                    'corporate customer':int(row['corporate customer'])}).toarray()[1])
result['ground truth'] = expected
result['profile'] = np.where(result['corporate customer'], 'Corporate Customer', 'Individual Customer')
result
# Out:
#    yearly consumption  corporate customer  frequency  predicted  ground truth  \
# 0                 0.0                 0.0      15134   0.068083         0.080
# 1                 0.0                 1.0       7487   0.001542         0.000
# 2                 1.0                 0.0      12374   0.149789         0.144
# 3                 1.0                 1.0      11305   0.005188         0.000
# 4                 2.0                 0.0      10097   0.211251         0.208
# 5                 2.0                 1.0      15008  -0.006681         0.000
# 6                 3.0                 0.0       7526   0.275063         0.272
# 7                 3.0                 1.0      18517  -0.003851         0.000
# 8                 4.0                 0.0       5186   0.335083         0.336
# 9                 4.0                 1.0      22366   0.009236         0.000
#
#                profile
# 0  Individual Customer
# 1   Corporate Customer
# 2  Individual Customer
# 3   Corporate Customer
# 4  Individual Customer
# 5   Corporate Customer
# 6  Individual Customer
# 7   Corporate Customer
# 8  Individual Customer
# 9   Corporate Customer

# %%
(ggplot(result.melt(id_vars=('yearly consumption', 'profile'), value_vars=['predicted','ground truth'], var_name='uplift')
, aes(x='yearly consumption', y='value', fill='uplift'))
 + geom_bar(stat='identity', position='dodge')
 + scale_y_continuous(name='uplift', labels=percent_format(), breaks=np.arange(0,2,0.1))
 + facet_wrap('~profile')
 + theme_light()
 + coord_flip()
 + ggtitle("Predicted & Theoretical Uplift From An Intervention On Coupon")
)
# Out:
# <ggplot: (198107298612)>

# %%
reshaped = result.melt(id_vars=('yearly consumption', 'profile'), 
                    value_vars=['predicted','ground truth'], 
                    var_name='uplift')
reshaped['yearly consumption'] = pd.Categorical(reshaped['yearly consumption'].astype('int'))
(ggplot(mapping=aes(x='yearly consumption', y='value', color='uplift', fill='uplift'))
 + geom_bar(reshaped[reshaped['uplift']=='predicted'],
            stat='identity', width=0.6)
 + geom_point(reshaped[reshaped['uplift']=='ground truth'], 
              size=3)
 + scale_y_continuous(name='uplift', labels=percent_format(), breaks=np.arange(0,2,0.1))
 + facet_wrap('~profile')
 + theme_bw()
 + scale_color_manual(values=('cornflowerblue','red'))
 + scale_fill_manual(values=('cornflowerblue','red'))
 + coord_flip()
 + ggtitle("Predicted & Theoretical Uplift From An Intervention On Coupon")
)
# Out:
# <ggplot: (198107838918)>

# %%
result['profile'] = np.where(result['corporate customer'], 'Corporate Customer', 'Individual Customer')
reshaped_2 = result.melt(id_vars=('yearly consumption', 'profile'), 
                    value_vars=['predicted'], 
                    var_name='uplift')
reshaped_2['yearly consumption'] = pd.Categorical(reshaped_2['yearly consumption'].astype('int'))

(ggplot(data=reshaped_2, mapping=aes(x='yearly consumption', y='value', color='uplift'))
 + geom_boxplot()
 + geom_point(reshaped[reshaped['uplift']=='ground truth'], 
              size=3)
 + scale_y_continuous(name='uplift', labels=percent_format(), breaks=np.arange(0,2,0.1))
 + facet_wrap('~profile')
 + theme_bw()
 + scale_color_manual(values=('cornflowerblue','red'))
 + coord_flip()
 + ggtitle("Predicted & Theoretical Uplift From An Intervention On Coupon")
)
# Out:
# <ggplot: (198110188520)>
